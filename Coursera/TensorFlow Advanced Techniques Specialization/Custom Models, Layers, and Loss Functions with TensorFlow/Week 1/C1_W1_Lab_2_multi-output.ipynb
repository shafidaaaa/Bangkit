# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 256.9523 - y1_output_loss: 115.4128 - y2_output_loss: 139.1359 - y1_output_root_mean_squared_error: 10.7942 - y2_output_root_mean_squared_error: 11.8506 - val_loss: 48.8724 - val_y1_output_loss: 19.0463 - val_y2_output_loss: 28.3897 - val_y1_output_root_mean_squared_error: 4.4393 - val_y2_output_root_mean_squared_error: 5.4005
# Epoch 2/500
# 614/614 [==============================] - 0s 187us/sample - loss: 34.2966 - y1_output_loss: 13.1946 - y2_output_loss: 21.0103 - y1_output_root_mean_squared_error: 3.6367 - y2_output_root_mean_squared_error: 4.5903 - val_loss: 40.1299 - val_y1_output_loss: 14.6694 - val_y2_output_loss: 24.8321 - val_y1_output_root_mean_squared_error: 3.8764 - val_y2_output_root_mean_squared_error: 5.0103
# Epoch 3/500
# 614/614 [==============================] - 0s 165us/sample - loss: 27.1871 - y1_output_loss: 10.1844 - y2_output_loss: 17.0771 - y1_output_root_mean_squared_error: 3.1861 - y2_output_root_mean_squared_error: 4.1275 - val_loss: 43.2568 - val_y1_output_loss: 14.2228 - val_y2_output_loss: 29.1673 - val_y1_output_root_mean_squared_error: 3.7831 - val_y2_output_root_mean_squared_error: 5.3800
# Epoch 4/500
# 614/614 [==============================] - 0s 160us/sample - loss: 24.2947 - y1_output_loss: 8.9988 - y2_output_loss: 15.5053 - y1_output_root_mean_squared_error: 2.9932 - y2_output_root_mean_squared_error: 3.9161 - val_loss: 32.6147 - val_y1_output_loss: 12.4170 - val_y2_output_loss: 19.6375 - val_y1_output_root_mean_squared_error: 3.5616 - val_y2_output_root_mean_squared_error: 4.4643
# Epoch 5/500
# 614/614 [==============================] - 0s 170us/sample - loss: 23.8319 - y1_output_loss: 8.9541 - y2_output_loss: 14.7706 - y1_output_root_mean_squared_error: 2.9984 - y2_output_root_mean_squared_error: 3.8524 - val_loss: 24.7016 - val_y1_output_loss: 12.5085 - val_y2_output_loss: 11.6618 - val_y1_output_root_mean_squared_error: 3.5782 - val_y2_output_root_mean_squared_error: 3.4494
# Epoch 6/500
# 614/614 [==============================] - 0s 170us/sample - loss: 22.6160 - y1_output_loss: 8.7600 - y2_output_loss: 13.7734 - y1_output_root_mean_squared_error: 2.9716 - y2_output_root_mean_squared_error: 3.7129 - val_loss: 19.0787 - val_y1_output_loss: 8.4710 - val_y2_output_loss: 10.1588 - val_y1_output_root_mean_squared_error: 2.9534 - val_y2_output_root_mean_squared_error: 3.2181
# Epoch 7/500
# 614/614 [==============================] - 0s 163us/sample - loss: 21.7434 - y1_output_loss: 8.3400 - y2_output_loss: 13.3779 - y1_output_root_mean_squared_error: 2.8777 - y2_output_root_mean_squared_error: 3.6691 - val_loss: 23.5920 - val_y1_output_loss: 10.6710 - val_y2_output_loss: 12.4442 - val_y1_output_root_mean_squared_error: 3.3060 - val_y2_output_root_mean_squared_error: 3.5584
# Epoch 8/500
# 614/614 [==============================] - 0s 165us/sample - loss: 23.2606 - y1_output_loss: 8.2543 - y2_output_loss: 14.8235 - y1_output_root_mean_squared_error: 2.8859 - y2_output_root_mean_squared_error: 3.8642 - val_loss: 19.8034 - val_y1_output_loss: 9.0156 - val_y2_output_loss: 10.2456 - val_y1_output_root_mean_squared_error: 3.0521 - val_y2_output_root_mean_squared_error: 3.2385
# Epoch 9/500
# 614/614 [==============================] - 0s 158us/sample - loss: 20.6697 - y1_output_loss: 7.7152 - y2_output_loss: 12.9127 - y1_output_root_mean_squared_error: 2.7834 - y2_output_root_mean_squared_error: 3.5948 - val_loss: 32.9896 - val_y1_output_loss: 9.5086 - val_y2_output_loss: 22.7300 - val_y1_output_root_mean_squared_error: 3.1339 - val_y2_output_root_mean_squared_error: 4.8134
# Epoch 10/500
# 614/614 [==============================] - 0s 162us/sample - loss: 24.9113 - y1_output_loss: 8.3730 - y2_output_loss: 16.3147 - y1_output_root_mean_squared_error: 2.9072 - y2_output_root_mean_squared_error: 4.0571 - val_loss: 21.5323 - val_y1_output_loss: 9.9498 - val_y2_output_loss: 11.0788 - val_y1_output_root_mean_squared_error: 3.1971 - val_y2_output_root_mean_squared_error: 3.3632
# Epoch 11/500
# 614/614 [==============================] - 0s 158us/sample - loss: 19.1496 - y1_output_loss: 7.3856 - y2_output_loss: 11.6089 - y1_output_root_mean_squared_error: 2.7281 - y2_output_root_mean_squared_error: 3.4215 - val_loss: 18.2047 - val_y1_output_loss: 8.2530 - val_y2_output_loss: 9.6377 - val_y1_output_root_mean_squared_error: 2.9110 - val_y2_output_root_mean_squared_error: 3.1194
# Epoch 12/500
# 614/614 [==============================] - 0s 168us/sample - loss: 17.9945 - y1_output_loss: 6.9868 - y2_output_loss: 10.8594 - y1_output_root_mean_squared_error: 2.6525 - y2_output_root_mean_squared_error: 3.3104 - val_loss: 21.0680 - val_y1_output_loss: 8.4104 - val_y2_output_loss: 12.4024 - val_y1_output_root_mean_squared_error: 2.9356 - val_y2_output_root_mean_squared_error: 3.5285
# Epoch 13/500
# 614/614 [==============================] - 0s 152us/sample - loss: 17.4383 - y1_output_loss: 6.6257 - y2_output_loss: 10.8598 - y1_output_root_mean_squared_error: 2.5783 - y2_output_root_mean_squared_error: 3.2849 - val_loss: 44.4158 - val_y1_output_loss: 10.2091 - val_y2_output_loss: 33.4342 - val_y1_output_root_mean_squared_error: 3.2413 - val_y2_output_root_mean_squared_error: 5.8232
# Epoch 14/500
# 614/614 [==============================] - 0s 156us/sample - loss: 19.0921 - y1_output_loss: 6.9303 - y2_output_loss: 12.0560 - y1_output_root_mean_squared_error: 2.6390 - y2_output_root_mean_squared_error: 3.4825 - val_loss: 22.5727 - val_y1_output_loss: 8.0949 - val_y2_output_loss: 14.1118 - val_y1_output_root_mean_squared_error: 2.8787 - val_y2_output_root_mean_squared_error: 3.7796
# Epoch 15/500
# 614/614 [==============================] - 0s 161us/sample - loss: 17.9732 - y1_output_loss: 6.6863 - y2_output_loss: 11.1670 - y1_output_root_mean_squared_error: 2.5953 - y2_output_root_mean_squared_error: 3.3522 - val_loss: 15.0010 - val_y1_output_loss: 6.8667 - val_y2_output_loss: 7.7448 - val_y1_output_root_mean_squared_error: 2.6627 - val_y2_output_root_mean_squared_error: 2.8127
# Epoch 16/500
# 614/614 [==============================] - 0s 158us/sample - loss: 19.9725 - y1_output_loss: 6.7380 - y2_output_loss: 13.2221 - y1_output_root_mean_squared_error: 2.5839 - y2_output_root_mean_squared_error: 3.6464 - val_loss: 22.2747 - val_y1_output_loss: 9.3087 - val_y2_output_loss: 12.4687 - val_y1_output_root_mean_squared_error: 3.0898 - val_y2_output_root_mean_squared_error: 3.5676
# Epoch 17/500
# 614/614 [==============================] - 0s 180us/sample - loss: 15.5629 - y1_output_loss: 5.7516 - y2_output_loss: 9.7555 - y1_output_root_mean_squared_error: 2.4071 - y2_output_root_mean_squared_error: 3.1255 - val_loss: 23.3120 - val_y1_output_loss: 7.0223 - val_y2_output_loss: 15.8177 - val_y1_output_root_mean_squared_error: 2.6901 - val_y2_output_root_mean_squared_error: 4.0094
# Epoch 18/500
# 614/614 [==============================] - 0s 176us/sample - loss: 15.2076 - y1_output_loss: 5.8389 - y2_output_loss: 9.5418 - y1_output_root_mean_squared_error: 2.4070 - y2_output_root_mean_squared_error: 3.0682 - val_loss: 35.6621 - val_y1_output_loss: 9.5560 - val_y2_output_loss: 25.8081 - val_y1_output_root_mean_squared_error: 3.1115 - val_y2_output_root_mean_squared_error: 5.0971
# Epoch 19/500
# 614/614 [==============================] - 0s 175us/sample - loss: 16.4365 - y1_output_loss: 6.1259 - y2_output_loss: 10.2208 - y1_output_root_mean_squared_error: 2.4827 - y2_output_root_mean_squared_error: 3.2051 - val_loss: 15.8220 - val_y1_output_loss: 6.7967 - val_y2_output_loss: 8.7014 - val_y1_output_root_mean_squared_error: 2.6409 - val_y2_output_root_mean_squared_error: 2.9745
# Epoch 20/500
# 614/614 [==============================] - 0s 158us/sample - loss: 17.7500 - y1_output_loss: 6.2939 - y2_output_loss: 11.2940 - y1_output_root_mean_squared_error: 2.5196 - y2_output_root_mean_squared_error: 3.3767 - val_loss: 14.0406 - val_y1_output_loss: 5.9309 - val_y2_output_loss: 7.7363 - val_y1_output_root_mean_squared_error: 2.4742 - val_y2_output_root_mean_squared_error: 2.8141
# Epoch 21/500
# 614/614 [==============================] - 0s 161us/sample - loss: 16.1144 - y1_output_loss: 5.5843 - y2_output_loss: 10.4432 - y1_output_root_mean_squared_error: 2.3727 - y2_output_root_mean_squared_error: 3.2380 - val_loss: 12.9679 - val_y1_output_loss: 5.6519 - val_y2_output_loss: 6.9568 - val_y1_output_root_mean_squared_error: 2.4194 - val_y2_output_root_mean_squared_error: 2.6673
# Epoch 22/500
# 614/614 [==============================] - 0s 152us/sample - loss: 13.0957 - y1_output_loss: 4.9467 - y2_output_loss: 8.0391 - y1_output_root_mean_squared_error: 2.2339 - y2_output_root_mean_squared_error: 2.8470 - val_loss: 14.3454 - val_y1_output_loss: 5.7534 - val_y2_output_loss: 8.2558 - val_y1_output_root_mean_squared_error: 2.4401 - val_y2_output_root_mean_squared_error: 2.8968
# Epoch 23/500
# 614/614 [==============================] - 0s 166us/sample - loss: 18.5958 - y1_output_loss: 6.1164 - y2_output_loss: 12.4992 - y1_output_root_mean_squared_error: 2.4747 - y2_output_root_mean_squared_error: 3.5315 - val_loss: 44.4394 - val_y1_output_loss: 9.2789 - val_y2_output_loss: 35.1119 - val_y1_output_root_mean_squared_error: 3.0544 - val_y2_output_root_mean_squared_error: 5.9254
# Epoch 24/500
# 614/614 [==============================] - 0s 174us/sample - loss: 15.4482 - y1_output_loss: 5.3678 - y2_output_loss: 10.1690 - y1_output_root_mean_squared_error: 2.3130 - y2_output_root_mean_squared_error: 3.1777 - val_loss: 14.6305 - val_y1_output_loss: 5.8014 - val_y2_output_loss: 8.6050 - val_y1_output_root_mean_squared_error: 2.4376 - val_y2_output_root_mean_squared_error: 2.9476
# Epoch 25/500
# 614/614 [==============================] - 0s 152us/sample - loss: 13.5991 - y1_output_loss: 5.0265 - y2_output_loss: 8.5058 - y1_output_root_mean_squared_error: 2.2529 - y2_output_root_mean_squared_error: 2.9195 - val_loss: 14.3959 - val_y1_output_loss: 6.5774 - val_y2_output_loss: 7.3499 - val_y1_output_root_mean_squared_error: 2.6083 - val_y2_output_root_mean_squared_error: 2.7555
# Epoch 26/500
# 614/614 [==============================] - 0s 160us/sample - loss: 12.6813 - y1_output_loss: 4.5011 - y2_output_loss: 8.3357 - y1_output_root_mean_squared_error: 2.1152 - y2_output_root_mean_squared_error: 2.8648 - val_loss: 16.1396 - val_y1_output_loss: 6.6978 - val_y2_output_loss: 9.0996 - val_y1_output_root_mean_squared_error: 2.6281 - val_y2_output_root_mean_squared_error: 3.0385
# Epoch 27/500
# 614/614 [==============================] - 0s 160us/sample - loss: 11.8241 - y1_output_loss: 4.3229 - y2_output_loss: 7.5320 - y1_output_root_mean_squared_error: 2.0753 - y2_output_root_mean_squared_error: 2.7417 - val_loss: 17.7727 - val_y1_output_loss: 6.8056 - val_y2_output_loss: 10.4373 - val_y1_output_root_mean_squared_error: 2.6488 - val_y2_output_root_mean_squared_error: 3.2797
# Epoch 28/500
# 614/614 [==============================] - 0s 182us/sample - loss: 12.0098 - y1_output_loss: 4.5159 - y2_output_loss: 7.6166 - y1_output_root_mean_squared_error: 2.1203 - y2_output_root_mean_squared_error: 2.7412 - val_loss: 24.7678 - val_y1_output_loss: 5.7274 - val_y2_output_loss: 18.6158 - val_y1_output_root_mean_squared_error: 2.4241 - val_y2_output_root_mean_squared_error: 4.3464
# Epoch 29/500
# 614/614 [==============================] - 0s 170us/sample - loss: 10.6412 - y1_output_loss: 3.7894 - y2_output_loss: 6.8104 - y1_output_root_mean_squared_error: 1.9425 - y2_output_root_mean_squared_error: 2.6207 - val_loss: 9.2765 - val_y1_output_loss: 3.9514 - val_y2_output_loss: 5.0679 - val_y1_output_root_mean_squared_error: 2.0248 - val_y2_output_root_mean_squared_error: 2.2753
# Epoch 30/500
# 614/614 [==============================] - 0s 210us/sample - loss: 10.9568 - y1_output_loss: 3.7729 - y2_output_loss: 7.1673 - y1_output_root_mean_squared_error: 1.9388 - y2_output_root_mean_squared_error: 2.6829 - val_loss: 13.3137 - val_y1_output_loss: 4.5664 - val_y2_output_loss: 8.5088 - val_y1_output_root_mean_squared_error: 2.1756 - val_y2_output_root_mean_squared_error: 2.9293
# Epoch 31/500
# 614/614 [==============================] - 0s 178us/sample - loss: 10.5694 - y1_output_loss: 3.8208 - y2_output_loss: 6.7168 - y1_output_root_mean_squared_error: 1.9614 - y2_output_root_mean_squared_error: 2.5927 - val_loss: 18.7603 - val_y1_output_loss: 5.8821 - val_y2_output_loss: 12.6278 - val_y1_output_root_mean_squared_error: 2.4466 - val_y2_output_root_mean_squared_error: 3.5741
# Epoch 32/500
# 614/614 [==============================] - 0s 178us/sample - loss: 11.2406 - y1_output_loss: 3.9500 - y2_output_loss: 7.2171 - y1_output_root_mean_squared_error: 1.9894 - y2_output_root_mean_squared_error: 2.6987 - val_loss: 9.5468 - val_y1_output_loss: 4.1350 - val_y2_output_loss: 5.1887 - val_y1_output_root_mean_squared_error: 2.0648 - val_y2_output_root_mean_squared_error: 2.2985
# Epoch 33/500
# 614/614 [==============================] - 0s 173us/sample - loss: 11.3924 - y1_output_loss: 3.6315 - y2_output_loss: 7.6849 - y1_output_root_mean_squared_error: 1.9070 - y2_output_root_mean_squared_error: 2.7849 - val_loss: 12.3237 - val_y1_output_loss: 4.2550 - val_y2_output_loss: 7.8117 - val_y1_output_root_mean_squared_error: 2.0999 - val_y2_output_root_mean_squared_error: 2.8132
# Epoch 34/500
# 614/614 [==============================] - 0s 151us/sample - loss: 9.5952 - y1_output_loss: 3.4846 - y2_output_loss: 6.0425 - y1_output_root_mean_squared_error: 1.8712 - y2_output_root_mean_squared_error: 2.4685 - val_loss: 9.1117 - val_y1_output_loss: 3.9995 - val_y2_output_loss: 4.8443 - val_y1_output_root_mean_squared_error: 2.0348 - val_y2_output_root_mean_squared_error: 2.2297
# Epoch 35/500
# 614/614 [==============================] - 0s 157us/sample - loss: 9.2406 - y1_output_loss: 3.1244 - y2_output_loss: 6.0539 - y1_output_root_mean_squared_error: 1.7750 - y2_output_root_mean_squared_error: 2.4678 - val_loss: 8.3686 - val_y1_output_loss: 3.4364 - val_y2_output_loss: 4.6945 - val_y1_output_root_mean_squared_error: 1.8868 - val_y2_output_root_mean_squared_error: 2.1929
# Epoch 36/500
# 614/614 [==============================] - 0s 154us/sample - loss: 10.4523 - y1_output_loss: 3.6894 - y2_output_loss: 6.6826 - y1_output_root_mean_squared_error: 1.9286 - y2_output_root_mean_squared_error: 2.5947 - val_loss: 8.6365 - val_y1_output_loss: 3.4350 - val_y2_output_loss: 4.9087 - val_y1_output_root_mean_squared_error: 1.8884 - val_y2_output_root_mean_squared_error: 2.2517
# Epoch 37/500
# 614/614 [==============================] - 0s 176us/sample - loss: 14.0167 - y1_output_loss: 4.3228 - y2_output_loss: 9.5749 - y1_output_root_mean_squared_error: 2.0875 - y2_output_root_mean_squared_error: 3.1079 - val_loss: 9.5051 - val_y1_output_loss: 3.5334 - val_y2_output_loss: 5.7306 - val_y1_output_root_mean_squared_error: 1.9090 - val_y2_output_root_mean_squared_error: 2.4209
# Epoch 38/500
# 614/614 [==============================] - 0s 183us/sample - loss: 7.6789 - y1_output_loss: 2.7774 - y2_output_loss: 4.8411 - y1_output_root_mean_squared_error: 1.6710 - y2_output_root_mean_squared_error: 2.2106 - val_loss: 7.8181 - val_y1_output_loss: 3.0648 - val_y2_output_loss: 4.6268 - val_y1_output_root_mean_squared_error: 1.7783 - val_y2_output_root_mean_squared_error: 2.1577
# Epoch 39/500
# 614/614 [==============================] - 0s 177us/sample - loss: 8.4377 - y1_output_loss: 2.9112 - y2_output_loss: 5.5077 - y1_output_root_mean_squared_error: 1.7123 - y2_output_root_mean_squared_error: 2.3464 - val_loss: 9.0737 - val_y1_output_loss: 3.0858 - val_y2_output_loss: 5.8261 - val_y1_output_root_mean_squared_error: 1.7856 - val_y2_output_root_mean_squared_error: 2.4260
# Epoch 40/500
# 614/614 [==============================] - 0s 180us/sample - loss: 7.3808 - y1_output_loss: 2.7038 - y2_output_loss: 4.6770 - y1_output_root_mean_squared_error: 1.6464 - y2_output_root_mean_squared_error: 2.1611 - val_loss: 12.7821 - val_y1_output_loss: 4.0774 - val_y2_output_loss: 8.5834 - val_y1_output_root_mean_squared_error: 2.0485 - val_y2_output_root_mean_squared_error: 2.9301
# Epoch 41/500
# 614/614 [==============================] - 0s 174us/sample - loss: 11.4136 - y1_output_loss: 3.5169 - y2_output_loss: 7.8463 - y1_output_root_mean_squared_error: 1.8773 - y2_output_root_mean_squared_error: 2.8088 - val_loss: 8.5648 - val_y1_output_loss: 3.1454 - val_y2_output_loss: 5.2455 - val_y1_output_root_mean_squared_error: 1.8016 - val_y2_output_root_mean_squared_error: 2.3063
# Epoch 42/500
# 614/614 [==============================] - 0s 177us/sample - loss: 8.2710 - y1_output_loss: 2.8236 - y2_output_loss: 5.3964 - y1_output_root_mean_squared_error: 1.6866 - y2_output_root_mean_squared_error: 2.3295 - val_loss: 16.7730 - val_y1_output_loss: 5.1040 - val_y2_output_loss: 11.4410 - val_y1_output_root_mean_squared_error: 2.2913 - val_y2_output_root_mean_squared_error: 3.3945
# Epoch 43/500
# 614/614 [==============================] - 0s 185us/sample - loss: 7.2597 - y1_output_loss: 2.5013 - y2_output_loss: 4.7807 - y1_output_root_mean_squared_error: 1.5887 - y2_output_root_mean_squared_error: 2.1762 - val_loss: 12.6159 - val_y1_output_loss: 3.5345 - val_y2_output_loss: 8.7876 - val_y1_output_root_mean_squared_error: 1.9102 - val_y2_output_root_mean_squared_error: 2.9945
# Epoch 44/500
# 614/614 [==============================] - 0s 187us/sample - loss: 8.2812 - y1_output_loss: 2.7190 - y2_output_loss: 5.5270 - y1_output_root_mean_squared_error: 1.6519 - y2_output_root_mean_squared_error: 2.3564 - val_loss: 9.5213 - val_y1_output_loss: 3.5227 - val_y2_output_loss: 5.9319 - val_y1_output_root_mean_squared_error: 1.8982 - val_y2_output_root_mean_squared_error: 2.4327
# Epoch 45/500
# 614/614 [==============================] - 0s 166us/sample - loss: 7.7822 - y1_output_loss: 2.6977 - y2_output_loss: 5.0816 - y1_output_root_mean_squared_error: 1.6375 - y2_output_root_mean_squared_error: 2.2585 - val_loss: 9.1304 - val_y1_output_loss: 3.1524 - val_y2_output_loss: 5.8390 - val_y1_output_root_mean_squared_error: 1.7963 - val_y2_output_root_mean_squared_error: 2.4298
# Epoch 46/500
# 614/614 [==============================] - 0s 154us/sample - loss: 8.3173 - y1_output_loss: 2.7254 - y2_output_loss: 5.5973 - y1_output_root_mean_squared_error: 1.6553 - y2_output_root_mean_squared_error: 2.3616 - val_loss: 18.7767 - val_y1_output_loss: 4.2056 - val_y2_output_loss: 14.4494 - val_y1_output_root_mean_squared_error: 2.0607 - val_y2_output_root_mean_squared_error: 3.8119
# Epoch 47/500
# 614/614 [==============================] - 0s 166us/sample - loss: 7.2473 - y1_output_loss: 2.3772 - y2_output_loss: 4.8724 - y1_output_root_mean_squared_error: 1.5480 - y2_output_root_mean_squared_error: 2.2025 - val_loss: 7.6090 - val_y1_output_loss: 2.6649 - val_y2_output_loss: 4.8837 - val_y1_output_root_mean_squared_error: 1.6457 - val_y2_output_root_mean_squared_error: 2.2137
# Epoch 48/500
# 614/614 [==============================] - 0s 177us/sample - loss: 7.9982 - y1_output_loss: 2.6504 - y2_output_loss: 5.3412 - y1_output_root_mean_squared_error: 1.6302 - y2_output_root_mean_squared_error: 2.3110 - val_loss: 6.2234 - val_y1_output_loss: 2.5092 - val_y2_output_loss: 3.6061 - val_y1_output_root_mean_squared_error: 1.6083 - val_y2_output_root_mean_squared_error: 1.9070
# Epoch 49/500
# 614/614 [==============================] - 0s 192us/sample - loss: 7.0495 - y1_output_loss: 2.2384 - y2_output_loss: 4.8442 - y1_output_root_mean_squared_error: 1.4930 - y2_output_root_mean_squared_error: 2.1955 - val_loss: 8.3228 - val_y1_output_loss: 3.0660 - val_y2_output_loss: 5.0785 - val_y1_output_root_mean_squared_error: 1.7780 - val_y2_output_root_mean_squared_error: 2.2719
# Epoch 50/500
# 614/614 [==============================] - 0s 181us/sample - loss: 6.8124 - y1_output_loss: 2.1574 - y2_output_loss: 4.6417 - y1_output_root_mean_squared_error: 1.4681 - y2_output_root_mean_squared_error: 2.1581 - val_loss: 11.8239 - val_y1_output_loss: 3.7330 - val_y2_output_loss: 8.1397 - val_y1_output_root_mean_squared_error: 1.9400 - val_y2_output_root_mean_squared_error: 2.8391
# Epoch 51/500
# 614/614 [==============================] - 0s 167us/sample - loss: 8.3385 - y1_output_loss: 2.5634 - y2_output_loss: 5.7217 - y1_output_root_mean_squared_error: 1.6064 - y2_output_root_mean_squared_error: 2.3996 - val_loss: 12.0947 - val_y1_output_loss: 3.6953 - val_y2_output_loss: 8.3089 - val_y1_output_root_mean_squared_error: 1.9453 - val_y2_output_root_mean_squared_error: 2.8828
# Epoch 52/500
# 614/614 [==============================] - 0s 174us/sample - loss: 9.0854 - y1_output_loss: 2.6721 - y2_output_loss: 6.3769 - y1_output_root_mean_squared_error: 1.6383 - y2_output_root_mean_squared_error: 2.5301 - val_loss: 9.1334 - val_y1_output_loss: 2.8163 - val_y2_output_loss: 6.3262 - val_y1_output_root_mean_squared_error: 1.6903 - val_y2_output_root_mean_squared_error: 2.5053
# Epoch 53/500
# 614/614 [==============================] - 0s 160us/sample - loss: 8.1051 - y1_output_loss: 2.5994 - y2_output_loss: 5.4430 - y1_output_root_mean_squared_error: 1.6168 - y2_output_root_mean_squared_error: 2.3433 - val_loss: 5.7073 - val_y1_output_loss: 2.2734 - val_y2_output_loss: 3.3560 - val_y1_output_root_mean_squared_error: 1.5294 - val_y2_output_root_mean_squared_error: 1.8353
# Epoch 54/500
# 614/614 [==============================] - 0s 178us/sample - loss: 6.2163 - y1_output_loss: 1.8240 - y2_output_loss: 4.3540 - y1_output_root_mean_squared_error: 1.3556 - y2_output_root_mean_squared_error: 2.0926 - val_loss: 13.0812 - val_y1_output_loss: 3.9729 - val_y2_output_loss: 9.0488 - val_y1_output_root_mean_squared_error: 1.9993 - val_y2_output_root_mean_squared_error: 3.0139
# Epoch 55/500
# 614/614 [==============================] - 0s 161us/sample - loss: 7.3079 - y1_output_loss: 2.0536 - y2_output_loss: 5.1870 - y1_output_root_mean_squared_error: 1.4399 - y2_output_root_mean_squared_error: 2.2879 - val_loss: 6.3959 - val_y1_output_loss: 2.3438 - val_y2_output_loss: 3.9214 - val_y1_output_root_mean_squared_error: 1.5540 - val_y2_output_root_mean_squared_error: 1.9953
# Epoch 56/500
# 614/614 [==============================] - 0s 156us/sample - loss: 5.2259 - y1_output_loss: 1.7953 - y2_output_loss: 3.4194 - y1_output_root_mean_squared_error: 1.3380 - y2_output_root_mean_squared_error: 1.8536 - val_loss: 5.5536 - val_y1_output_loss: 1.8769 - val_y2_output_loss: 3.7338 - val_y1_output_root_mean_squared_error: 1.3759 - val_y2_output_root_mean_squared_error: 1.9133
# Epoch 57/500
# 614/614 [==============================] - 0s 178us/sample - loss: 6.8067 - y1_output_loss: 2.1033 - y2_output_loss: 4.6453 - y1_output_root_mean_squared_error: 1.4564 - y2_output_root_mean_squared_error: 2.1646 - val_loss: 5.3775 - val_y1_output_loss: 1.7954 - val_y2_output_loss: 3.4866 - val_y1_output_root_mean_squared_error: 1.3607 - val_y2_output_root_mean_squared_error: 1.8778
# Epoch 58/500
# 614/614 [==============================] - 0s 181us/sample - loss: 6.0632 - y1_output_loss: 1.9050 - y2_output_loss: 4.1168 - y1_output_root_mean_squared_error: 1.3832 - y2_output_root_mean_squared_error: 2.0372 - val_loss: 6.5591 - val_y1_output_loss: 1.7881 - val_y2_output_loss: 4.8461 - val_y1_output_root_mean_squared_error: 1.3422 - val_y2_output_root_mean_squared_error: 2.1812
# Epoch 59/500
# 614/614 [==============================] - 0s 187us/sample - loss: 6.0659 - y1_output_loss: 1.8433 - y2_output_loss: 4.1770 - y1_output_root_mean_squared_error: 1.3609 - y2_output_root_mean_squared_error: 2.0528 - val_loss: 6.6389 - val_y1_output_loss: 2.3202 - val_y2_output_loss: 4.3133 - val_y1_output_root_mean_squared_error: 1.5392 - val_y2_output_root_mean_squared_error: 2.0663
# Epoch 60/500
# 614/614 [==============================] - 0s 167us/sample - loss: 8.1101 - y1_output_loss: 2.3032 - y2_output_loss: 5.7350 - y1_output_root_mean_squared_error: 1.5248 - y2_output_root_mean_squared_error: 2.4052 - val_loss: 5.9807 - val_y1_output_loss: 2.0775 - val_y2_output_loss: 3.8292 - val_y1_output_root_mean_squared_error: 1.4575 - val_y2_output_root_mean_squared_error: 1.9638
# Epoch 61/500
# 614/614 [==============================] - 0s 163us/sample - loss: 6.8806 - y1_output_loss: 2.0231 - y2_output_loss: 4.8472 - y1_output_root_mean_squared_error: 1.4263 - y2_output_root_mean_squared_error: 2.2014 - val_loss: 28.6512 - val_y1_output_loss: 9.1734 - val_y2_output_loss: 19.0413 - val_y1_output_root_mean_squared_error: 3.0682 - val_y2_output_root_mean_squared_error: 4.3860
# Epoch 62/500
# 614/614 [==============================] - 0s 168us/sample - loss: 10.7486 - y1_output_loss: 3.4313 - y2_output_loss: 7.2355 - y1_output_root_mean_squared_error: 1.8575 - y2_output_root_mean_squared_error: 2.7015 - val_loss: 5.7757 - val_y1_output_loss: 1.7998 - val_y2_output_loss: 3.9026 - val_y1_output_root_mean_squared_error: 1.3628 - val_y2_output_root_mean_squared_error: 1.9795
# Epoch 63/500
# 614/614 [==============================] - 0s 170us/sample - loss: 6.6275 - y1_output_loss: 1.9257 - y2_output_loss: 4.7494 - y1_output_root_mean_squared_error: 1.3854 - y2_output_root_mean_squared_error: 2.1698 - val_loss: 18.0114 - val_y1_output_loss: 4.6685 - val_y2_output_loss: 13.2690 - val_y1_output_root_mean_squared_error: 2.1639 - val_y2_output_root_mean_squared_error: 3.6509
# Epoch 64/500
# 614/614 [==============================] - 0s 176us/sample - loss: 6.1367 - y1_output_loss: 1.7742 - y2_output_loss: 4.3370 - y1_output_root_mean_squared_error: 1.3349 - y2_output_root_mean_squared_error: 2.0868 - val_loss: 5.6217 - val_y1_output_loss: 1.5732 - val_y2_output_loss: 3.9731 - val_y1_output_root_mean_squared_error: 1.2728 - val_y2_output_root_mean_squared_error: 2.0004
# Epoch 65/500
# 614/614 [==============================] - 0s 171us/sample - loss: 5.3895 - y1_output_loss: 1.5545 - y2_output_loss: 3.8905 - y1_output_root_mean_squared_error: 1.2306 - y2_output_root_mean_squared_error: 1.9685 - val_loss: 10.4120 - val_y1_output_loss: 3.3934 - val_y2_output_loss: 7.0667 - val_y1_output_root_mean_squared_error: 1.8347 - val_y2_output_root_mean_squared_error: 2.6544
# Epoch 66/500
# 614/614 [==============================] - 0s 166us/sample - loss: 5.0073 - y1_output_loss: 1.3536 - y2_output_loss: 3.6341 - y1_output_root_mean_squared_error: 1.1614 - y2_output_root_mean_squared_error: 1.9127 - val_loss: 5.6030 - val_y1_output_loss: 2.0180 - val_y2_output_loss: 3.4852 - val_y1_output_root_mean_squared_error: 1.4394 - val_y2_output_root_mean_squared_error: 1.8791
# Epoch 67/500
# 614/614 [==============================] - 0s 158us/sample - loss: 10.5469 - y1_output_loss: 3.5697 - y2_output_loss: 6.9054 - y1_output_root_mean_squared_error: 1.8962 - y2_output_root_mean_squared_error: 2.6365 - val_loss: 4.7639 - val_y1_output_loss: 1.6251 - val_y2_output_loss: 3.0722 - val_y1_output_root_mean_squared_error: 1.2931 - val_y2_output_root_mean_squared_error: 1.7584
# Epoch 68/500
# 614/614 [==============================] - 0s 173us/sample - loss: 4.6294 - y1_output_loss: 1.4102 - y2_output_loss: 3.1993 - y1_output_root_mean_squared_error: 1.1908 - y2_output_root_mean_squared_error: 1.7920 - val_loss: 7.5605 - val_y1_output_loss: 2.0259 - val_y2_output_loss: 5.5507 - val_y1_output_root_mean_squared_error: 1.4352 - val_y2_output_root_mean_squared_error: 2.3454
# Epoch 69/500
# 614/614 [==============================] - 0s 202us/sample - loss: 4.0499 - y1_output_loss: 1.1785 - y2_output_loss: 2.8661 - y1_output_root_mean_squared_error: 1.0864 - y2_output_root_mean_squared_error: 1.6940 - val_loss: 6.8743 - val_y1_output_loss: 2.5584 - val_y2_output_loss: 4.1603 - val_y1_output_root_mean_squared_error: 1.6207 - val_y2_output_root_mean_squared_error: 2.0610
# Epoch 70/500
# 614/614 [==============================] - 0s 172us/sample - loss: 5.7305 - y1_output_loss: 1.5230 - y2_output_loss: 4.1760 - y1_output_root_mean_squared_error: 1.2388 - y2_output_root_mean_squared_error: 2.0484 - val_loss: 5.3534 - val_y1_output_loss: 1.0795 - val_y2_output_loss: 4.2999 - val_y1_output_root_mean_squared_error: 1.0509 - val_y2_output_root_mean_squared_error: 2.0613
# Epoch 71/500
# 614/614 [==============================] - 0s 171us/sample - loss: 4.5638 - y1_output_loss: 1.3578 - y2_output_loss: 3.1929 - y1_output_root_mean_squared_error: 1.1628 - y2_output_root_mean_squared_error: 1.7921 - val_loss: 5.3085 - val_y1_output_loss: 1.5839 - val_y2_output_loss: 3.6448 - val_y1_output_root_mean_squared_error: 1.2785 - val_y2_output_root_mean_squared_error: 1.9168
# Epoch 72/500
# 614/614 [==============================] - 0s 151us/sample - loss: 4.4577 - y1_output_loss: 1.1653 - y2_output_loss: 3.2991 - y1_output_root_mean_squared_error: 1.0826 - y2_output_root_mean_squared_error: 1.8126 - val_loss: 5.3240 - val_y1_output_loss: 1.2291 - val_y2_output_loss: 4.0178 - val_y1_output_root_mean_squared_error: 1.1263 - val_y2_output_root_mean_squared_error: 2.0138
# Epoch 73/500
# 614/614 [==============================] - 0s 157us/sample - loss: 4.6459 - y1_output_loss: 1.2934 - y2_output_loss: 3.3385 - y1_output_root_mean_squared_error: 1.1427 - y2_output_root_mean_squared_error: 1.8276 - val_loss: 4.6247 - val_y1_output_loss: 1.2443 - val_y2_output_loss: 3.3072 - val_y1_output_root_mean_squared_error: 1.1323 - val_y2_output_root_mean_squared_error: 1.8283
# Epoch 74/500
# 614/614 [==============================] - 0s 148us/sample - loss: 4.7099 - y1_output_loss: 1.2779 - y2_output_loss: 3.3989 - y1_output_root_mean_squared_error: 1.1334 - y2_output_root_mean_squared_error: 1.8507 - val_loss: 3.3881 - val_y1_output_loss: 1.0487 - val_y2_output_loss: 2.2729 - val_y1_output_root_mean_squared_error: 1.0407 - val_y2_output_root_mean_squared_error: 1.5182
# Epoch 75/500
# 614/614 [==============================] - 0s 174us/sample - loss: 4.1188 - y1_output_loss: 0.9402 - y2_output_loss: 3.1428 - y1_output_root_mean_squared_error: 0.9736 - y2_output_root_mean_squared_error: 1.7807 - val_loss: 3.7441 - val_y1_output_loss: 1.2680 - val_y2_output_loss: 2.4472 - val_y1_output_root_mean_squared_error: 1.1316 - val_y2_output_root_mean_squared_error: 1.5696
# Epoch 76/500
# 614/614 [==============================] - 0s 165us/sample - loss: 4.4364 - y1_output_loss: 1.1761 - y2_output_loss: 3.2311 - y1_output_root_mean_squared_error: 1.0887 - y2_output_root_mean_squared_error: 1.8031 - val_loss: 3.4324 - val_y1_output_loss: 1.0820 - val_y2_output_loss: 2.3252 - val_y1_output_root_mean_squared_error: 1.0478 - val_y2_output_root_mean_squared_error: 1.5279
# Epoch 77/500
# 614/614 [==============================] - 0s 156us/sample - loss: 3.7882 - y1_output_loss: 1.0859 - y2_output_loss: 2.6701 - y1_output_root_mean_squared_error: 1.0461 - y2_output_root_mean_squared_error: 1.6413 - val_loss: 3.1574 - val_y1_output_loss: 0.8221 - val_y2_output_loss: 2.2981 - val_y1_output_root_mean_squared_error: 0.9194 - val_y2_output_root_mean_squared_error: 1.5206
# Epoch 78/500
# 614/614 [==============================] - 0s 156us/sample - loss: 4.5532 - y1_output_loss: 1.2787 - y2_output_loss: 3.2345 - y1_output_root_mean_squared_error: 1.1357 - y2_output_root_mean_squared_error: 1.8065 - val_loss: 3.5142 - val_y1_output_loss: 0.9584 - val_y2_output_loss: 2.4744 - val_y1_output_root_mean_squared_error: 0.9959 - val_y2_output_root_mean_squared_error: 1.5882
# Epoch 79/500
# 614/614 [==============================] - 0s 160us/sample - loss: 3.1420 - y1_output_loss: 0.7428 - y2_output_loss: 2.3911 - y1_output_root_mean_squared_error: 0.8584 - y2_output_root_mean_squared_error: 1.5509 - val_loss: 8.7227 - val_y1_output_loss: 3.6101 - val_y2_output_loss: 4.9643 - val_y1_output_root_mean_squared_error: 1.9243 - val_y2_output_root_mean_squared_error: 2.2404
# Epoch 80/500
# 614/614 [==============================] - 0s 153us/sample - loss: 6.2946 - y1_output_loss: 1.8917 - y2_output_loss: 4.3716 - y1_output_root_mean_squared_error: 1.3798 - y2_output_root_mean_squared_error: 2.0954 - val_loss: 4.0271 - val_y1_output_loss: 0.8627 - val_y2_output_loss: 3.1640 - val_y1_output_root_mean_squared_error: 0.9393 - val_y2_output_root_mean_squared_error: 1.7733
# Epoch 81/500
# 614/614 [==============================] - 0s 167us/sample - loss: 3.2120 - y1_output_loss: 0.8345 - y2_output_loss: 2.3721 - y1_output_root_mean_squared_error: 0.9172 - y2_output_root_mean_squared_error: 1.5397 - val_loss: 2.7144 - val_y1_output_loss: 0.7212 - val_y2_output_loss: 1.9560 - val_y1_output_root_mean_squared_error: 0.8594 - val_y2_output_root_mean_squared_error: 1.4057
# Epoch 82/500
# 614/614 [==============================] - 0s 172us/sample - loss: 2.8692 - y1_output_loss: 0.7195 - y2_output_loss: 2.1534 - y1_output_root_mean_squared_error: 0.8446 - y2_output_root_mean_squared_error: 1.4683 - val_loss: 6.4663 - val_y1_output_loss: 1.2014 - val_y2_output_loss: 5.2777 - val_y1_output_root_mean_squared_error: 1.1032 - val_y2_output_root_mean_squared_error: 2.2911
# Epoch 83/500
# 614/614 [==============================] - 0s 166us/sample - loss: 3.3473 - y1_output_loss: 0.7595 - y2_output_loss: 2.5991 - y1_output_root_mean_squared_error: 0.8724 - y2_output_root_mean_squared_error: 1.6081 - val_loss: 4.7600 - val_y1_output_loss: 1.1520 - val_y2_output_loss: 3.5960 - val_y1_output_root_mean_squared_error: 1.0721 - val_y2_output_root_mean_squared_error: 1.9002
# Epoch 84/500
# 614/614 [==============================] - 0s 158us/sample - loss: 2.5763 - y1_output_loss: 0.6538 - y2_output_loss: 1.9079 - y1_output_root_mean_squared_error: 0.8096 - y2_output_root_mean_squared_error: 1.3859 - val_loss: 3.5513 - val_y1_output_loss: 0.7359 - val_y2_output_loss: 2.7522 - val_y1_output_root_mean_squared_error: 0.8671 - val_y2_output_root_mean_squared_error: 1.6732
# Epoch 85/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.5071 - y1_output_loss: 0.8567 - y2_output_loss: 2.6198 - y1_output_root_mean_squared_error: 0.9294 - y2_output_root_mean_squared_error: 1.6258 - val_loss: 2.6968 - val_y1_output_loss: 0.7592 - val_y2_output_loss: 1.8660 - val_y1_output_root_mean_squared_error: 0.8828 - val_y2_output_root_mean_squared_error: 1.3847
# Epoch 86/500
# 614/614 [==============================] - 0s 175us/sample - loss: 2.8589 - y1_output_loss: 0.7608 - y2_output_loss: 2.1492 - y1_output_root_mean_squared_error: 0.8748 - y2_output_root_mean_squared_error: 1.4469 - val_loss: 3.0824 - val_y1_output_loss: 0.7131 - val_y2_output_loss: 2.2795 - val_y1_output_root_mean_squared_error: 0.8588 - val_y2_output_root_mean_squared_error: 1.5313
# Epoch 87/500
# 614/614 [==============================] - 0s 165us/sample - loss: 3.1719 - y1_output_loss: 0.8123 - y2_output_loss: 2.3357 - y1_output_root_mean_squared_error: 0.9041 - y2_output_root_mean_squared_error: 1.5344 - val_loss: 2.6084 - val_y1_output_loss: 0.6795 - val_y2_output_loss: 1.8764 - val_y1_output_root_mean_squared_error: 0.8356 - val_y2_output_root_mean_squared_error: 1.3821
# Epoch 88/500
# 614/614 [==============================] - 0s 165us/sample - loss: 3.3067 - y1_output_loss: 0.8383 - y2_output_loss: 2.4402 - y1_output_root_mean_squared_error: 0.9191 - y2_output_root_mean_squared_error: 1.5690 - val_loss: 2.6636 - val_y1_output_loss: 0.7127 - val_y2_output_loss: 1.8903 - val_y1_output_root_mean_squared_error: 0.8521 - val_y2_output_root_mean_squared_error: 1.3920
# Epoch 89/500
# 614/614 [==============================] - 0s 166us/sample - loss: 2.7204 - y1_output_loss: 0.6032 - y2_output_loss: 2.1166 - y1_output_root_mean_squared_error: 0.7712 - y2_output_root_mean_squared_error: 1.4580 - val_loss: 3.4717 - val_y1_output_loss: 1.0940 - val_y2_output_loss: 2.3758 - val_y1_output_root_mean_squared_error: 1.0543 - val_y2_output_root_mean_squared_error: 1.5363
# Epoch 90/500
# 614/614 [==============================] - 0s 167us/sample - loss: 3.5648 - y1_output_loss: 0.9388 - y2_output_loss: 2.6047 - y1_output_root_mean_squared_error: 0.9687 - y2_output_root_mean_squared_error: 1.6206 - val_loss: 3.5670 - val_y1_output_loss: 1.0657 - val_y2_output_loss: 2.4532 - val_y1_output_root_mean_squared_error: 1.0421 - val_y2_output_root_mean_squared_error: 1.5751
# Epoch 91/500
# 614/614 [==============================] - 0s 172us/sample - loss: 3.2943 - y1_output_loss: 0.7667 - y2_output_loss: 2.5659 - y1_output_root_mean_squared_error: 0.8713 - y2_output_root_mean_squared_error: 1.5922 - val_loss: 6.5839 - val_y1_output_loss: 1.5242 - val_y2_output_loss: 5.2013 - val_y1_output_root_mean_squared_error: 1.2285 - val_y2_output_root_mean_squared_error: 2.2527
# Epoch 92/500
# 614/614 [==============================] - 0s 174us/sample - loss: 3.2136 - y1_output_loss: 0.7873 - y2_output_loss: 2.3976 - y1_output_root_mean_squared_error: 0.8903 - y2_output_root_mean_squared_error: 1.5559 - val_loss: 3.9255 - val_y1_output_loss: 0.8694 - val_y2_output_loss: 2.9840 - val_y1_output_root_mean_squared_error: 0.9470 - val_y2_output_root_mean_squared_error: 1.7403
# Epoch 93/500
# 614/614 [==============================] - 0s 167us/sample - loss: 3.2802 - y1_output_loss: 0.7915 - y2_output_loss: 2.4695 - y1_output_root_mean_squared_error: 0.8928 - y2_output_root_mean_squared_error: 1.5758 - val_loss: 3.2134 - val_y1_output_loss: 0.9896 - val_y2_output_loss: 2.1377 - val_y1_output_root_mean_squared_error: 1.0081 - val_y2_output_root_mean_squared_error: 1.4823
# Epoch 94/500
# 614/614 [==============================] - 0s 167us/sample - loss: 3.2319 - y1_output_loss: 0.8138 - y2_output_loss: 2.4078 - y1_output_root_mean_squared_error: 0.9059 - y2_output_root_mean_squared_error: 1.5528 - val_loss: 5.8142 - val_y1_output_loss: 0.7724 - val_y2_output_loss: 4.9618 - val_y1_output_root_mean_squared_error: 0.8881 - val_y2_output_root_mean_squared_error: 2.2418
# Epoch 95/500
# 614/614 [==============================] - 0s 170us/sample - loss: 2.8155 - y1_output_loss: 0.6577 - y2_output_loss: 2.1367 - y1_output_root_mean_squared_error: 0.8133 - y2_output_root_mean_squared_error: 1.4676 - val_loss: 2.9125 - val_y1_output_loss: 0.6193 - val_y2_output_loss: 2.2179 - val_y1_output_root_mean_squared_error: 0.8002 - val_y2_output_root_mean_squared_error: 1.5073
# Epoch 96/500
# 614/614 [==============================] - 0s 172us/sample - loss: 3.7692 - y1_output_loss: 0.9431 - y2_output_loss: 2.7944 - y1_output_root_mean_squared_error: 0.9741 - y2_output_root_mean_squared_error: 1.6794 - val_loss: 2.5504 - val_y1_output_loss: 0.5475 - val_y2_output_loss: 1.9484 - val_y1_output_root_mean_squared_error: 0.7508 - val_y2_output_root_mean_squared_error: 1.4095
# Epoch 97/500
# 614/614 [==============================] - 0s 185us/sample - loss: 3.0826 - y1_output_loss: 0.6551 - y2_output_loss: 2.4078 - y1_output_root_mean_squared_error: 0.8124 - y2_output_root_mean_squared_error: 1.5564 - val_loss: 2.4076 - val_y1_output_loss: 0.7083 - val_y2_output_loss: 1.6482 - val_y1_output_root_mean_squared_error: 0.8535 - val_y2_output_root_mean_squared_error: 1.2958
# Epoch 98/500
# 614/614 [==============================] - 0s 173us/sample - loss: 3.8813 - y1_output_loss: 0.9824 - y2_output_loss: 2.8772 - y1_output_root_mean_squared_error: 0.9951 - y2_output_root_mean_squared_error: 1.7003 - val_loss: 5.0858 - val_y1_output_loss: 1.4878 - val_y2_output_loss: 3.4816 - val_y1_output_root_mean_squared_error: 1.2418 - val_y2_output_root_mean_squared_error: 1.8825
# Epoch 99/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.4243 - y1_output_loss: 0.5793 - y2_output_loss: 1.8259 - y1_output_root_mean_squared_error: 0.7623 - y2_output_root_mean_squared_error: 1.3577 - val_loss: 2.2158 - val_y1_output_loss: 0.5755 - val_y2_output_loss: 1.6122 - val_y1_output_root_mean_squared_error: 0.7676 - val_y2_output_root_mean_squared_error: 1.2754
# Epoch 100/500
# 614/614 [==============================] - 0s 169us/sample - loss: 2.7551 - y1_output_loss: 0.6250 - y2_output_loss: 2.1450 - y1_output_root_mean_squared_error: 0.7920 - y2_output_root_mean_squared_error: 1.4587 - val_loss: 2.7834 - val_y1_output_loss: 0.6323 - val_y2_output_loss: 2.0851 - val_y1_output_root_mean_squared_error: 0.8074 - val_y2_output_root_mean_squared_error: 1.4600
# Epoch 101/500
# 614/614 [==============================] - 0s 160us/sample - loss: 2.2604 - y1_output_loss: 0.4946 - y2_output_loss: 1.7668 - y1_output_root_mean_squared_error: 0.7026 - y2_output_root_mean_squared_error: 1.3292 - val_loss: 3.6164 - val_y1_output_loss: 0.5601 - val_y2_output_loss: 3.0298 - val_y1_output_root_mean_squared_error: 0.7578 - val_y2_output_root_mean_squared_error: 1.7441
# Epoch 102/500
# 614/614 [==============================] - 0s 168us/sample - loss: 2.4622 - y1_output_loss: 0.5457 - y2_output_loss: 1.9163 - y1_output_root_mean_squared_error: 0.7364 - y2_output_root_mean_squared_error: 1.3856 - val_loss: 2.2454 - val_y1_output_loss: 0.5290 - val_y2_output_loss: 1.6533 - val_y1_output_root_mean_squared_error: 0.7389 - val_y2_output_root_mean_squared_error: 1.3036
# Epoch 103/500
# 614/614 [==============================] - 0s 158us/sample - loss: 2.9359 - y1_output_loss: 0.6745 - y2_output_loss: 2.3812 - y1_output_root_mean_squared_error: 0.7906 - y2_output_root_mean_squared_error: 1.5202 - val_loss: 6.1599 - val_y1_output_loss: 2.8691 - val_y2_output_loss: 3.1874 - val_y1_output_root_mean_squared_error: 1.7104 - val_y2_output_root_mean_squared_error: 1.7984
# Epoch 104/500
# 614/614 [==============================] - 0s 176us/sample - loss: 2.9398 - y1_output_loss: 0.7553 - y2_output_loss: 2.1782 - y1_output_root_mean_squared_error: 0.8689 - y2_output_root_mean_squared_error: 1.4781 - val_loss: 5.2854 - val_y1_output_loss: 0.8064 - val_y2_output_loss: 4.4126 - val_y1_output_root_mean_squared_error: 0.9128 - val_y2_output_root_mean_squared_error: 2.1100
# Epoch 105/500
# 614/614 [==============================] - 0s 170us/sample - loss: 2.1543 - y1_output_loss: 0.4951 - y2_output_loss: 1.6954 - y1_output_root_mean_squared_error: 0.6956 - y2_output_root_mean_squared_error: 1.2924 - val_loss: 7.0917 - val_y1_output_loss: 1.4354 - val_y2_output_loss: 5.7414 - val_y1_output_root_mean_squared_error: 1.1924 - val_y2_output_root_mean_squared_error: 2.3811
# Epoch 106/500
# 614/614 [==============================] - 0s 161us/sample - loss: 2.4089 - y1_output_loss: 0.5642 - y2_output_loss: 1.8241 - y1_output_root_mean_squared_error: 0.7537 - y2_output_root_mean_squared_error: 1.3568 - val_loss: 2.3676 - val_y1_output_loss: 0.4214 - val_y2_output_loss: 1.9152 - val_y1_output_root_mean_squared_error: 0.6591 - val_y2_output_root_mean_squared_error: 1.3904
# Epoch 107/500
# 614/614 [==============================] - 0s 181us/sample - loss: 2.3184 - y1_output_loss: 0.5185 - y2_output_loss: 1.7785 - y1_output_root_mean_squared_error: 0.7234 - y2_output_root_mean_squared_error: 1.3398 - val_loss: 2.9304 - val_y1_output_loss: 0.5811 - val_y2_output_loss: 2.3064 - val_y1_output_root_mean_squared_error: 0.7647 - val_y2_output_root_mean_squared_error: 1.5315
# Epoch 108/500
# 614/614 [==============================] - 0s 176us/sample - loss: 2.6562 - y1_output_loss: 0.5714 - y2_output_loss: 2.1242 - y1_output_root_mean_squared_error: 0.7581 - y2_output_root_mean_squared_error: 1.4428 - val_loss: 12.2204 - val_y1_output_loss: 0.9718 - val_y2_output_loss: 11.2090 - val_y1_output_root_mean_squared_error: 0.9953 - val_y2_output_root_mean_squared_error: 3.3511
# Epoch 109/500
# 614/614 [==============================] - 0s 179us/sample - loss: 2.8644 - y1_output_loss: 0.7006 - y2_output_loss: 2.1464 - y1_output_root_mean_squared_error: 0.8382 - y2_output_root_mean_squared_error: 1.4703 - val_loss: 2.5129 - val_y1_output_loss: 0.6547 - val_y2_output_loss: 1.8014 - val_y1_output_root_mean_squared_error: 0.8155 - val_y2_output_root_mean_squared_error: 1.3593
# Epoch 110/500
# 614/614 [==============================] - 0s 167us/sample - loss: 2.0138 - y1_output_loss: 0.4240 - y2_output_loss: 1.5843 - y1_output_root_mean_squared_error: 0.6506 - y2_output_root_mean_squared_error: 1.2611 - val_loss: 21.6030 - val_y1_output_loss: 8.4579 - val_y2_output_loss: 12.6418 - val_y1_output_root_mean_squared_error: 2.9397 - val_y2_output_root_mean_squared_error: 3.6002
# Epoch 111/500
# 614/614 [==============================] - 0s 166us/sample - loss: 4.7752 - y1_output_loss: 1.1652 - y2_output_loss: 3.5948 - y1_output_root_mean_squared_error: 1.0840 - y2_output_root_mean_squared_error: 1.8974 - val_loss: 2.7534 - val_y1_output_loss: 0.6618 - val_y2_output_loss: 2.0253 - val_y1_output_root_mean_squared_error: 0.8235 - val_y2_output_root_mean_squared_error: 1.4406
# Epoch 112/500
# 614/614 [==============================] - 0s 169us/sample - loss: 3.5576 - y1_output_loss: 0.8582 - y2_output_loss: 2.6692 - y1_output_root_mean_squared_error: 0.9305 - y2_output_root_mean_squared_error: 1.6407 - val_loss: 1.9281 - val_y1_output_loss: 0.4354 - val_y2_output_loss: 1.4638 - val_y1_output_root_mean_squared_error: 0.6692 - val_y2_output_root_mean_squared_error: 1.2167
# Epoch 113/500
# 614/614 [==============================] - 0s 170us/sample - loss: 2.0903 - y1_output_loss: 0.5101 - y2_output_loss: 1.5649 - y1_output_root_mean_squared_error: 0.7168 - y2_output_root_mean_squared_error: 1.2556 - val_loss: 2.3456 - val_y1_output_loss: 0.4605 - val_y2_output_loss: 1.8189 - val_y1_output_root_mean_squared_error: 0.6888 - val_y2_output_root_mean_squared_error: 1.3679
# Epoch 114/500
# 614/614 [==============================] - 0s 159us/sample - loss: 2.7395 - y1_output_loss: 0.6776 - y2_output_loss: 2.1230 - y1_output_root_mean_squared_error: 0.8189 - y2_output_root_mean_squared_error: 1.4384 - val_loss: 4.8786 - val_y1_output_loss: 1.2323 - val_y2_output_loss: 3.5356 - val_y1_output_root_mean_squared_error: 1.1244 - val_y2_output_root_mean_squared_error: 1.9011
# Epoch 115/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.4228 - y1_output_loss: 0.6210 - y2_output_loss: 1.7800 - y1_output_root_mean_squared_error: 0.7909 - y2_output_root_mean_squared_error: 1.3406 - val_loss: 2.1022 - val_y1_output_loss: 0.4819 - val_y2_output_loss: 1.5635 - val_y1_output_root_mean_squared_error: 0.7039 - val_y2_output_root_mean_squared_error: 1.2676
# Epoch 116/500
# 614/614 [==============================] - 0s 162us/sample - loss: 1.6625 - y1_output_loss: 0.3575 - y2_output_loss: 1.2961 - y1_output_root_mean_squared_error: 0.5994 - y2_output_root_mean_squared_error: 1.1416 - val_loss: 1.9292 - val_y1_output_loss: 0.4689 - val_y2_output_loss: 1.4141 - val_y1_output_root_mean_squared_error: 0.6929 - val_y2_output_root_mean_squared_error: 1.2038
# Epoch 117/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.2491 - y1_output_loss: 0.5074 - y2_output_loss: 1.7348 - y1_output_root_mean_squared_error: 0.7138 - y2_output_root_mean_squared_error: 1.3189 - val_loss: 2.5702 - val_y1_output_loss: 0.6481 - val_y2_output_loss: 1.8677 - val_y1_output_root_mean_squared_error: 0.8109 - val_y2_output_root_mean_squared_error: 1.3830
# Epoch 118/500
# 614/614 [==============================] - 0s 175us/sample - loss: 1.7241 - y1_output_loss: 0.3883 - y2_output_loss: 1.4662 - y1_output_root_mean_squared_error: 0.6249 - y2_output_root_mean_squared_error: 1.1548 - val_loss: 10.3071 - val_y1_output_loss: 1.1238 - val_y2_output_loss: 8.9275 - val_y1_output_root_mean_squared_error: 1.0749 - val_y2_output_root_mean_squared_error: 3.0252
# Epoch 119/500
# 614/614 [==============================] - 0s 174us/sample - loss: 3.2460 - y1_output_loss: 0.6966 - y2_output_loss: 2.6052 - y1_output_root_mean_squared_error: 0.8279 - y2_output_root_mean_squared_error: 1.6002 - val_loss: 7.2344 - val_y1_output_loss: 1.8056 - val_y2_output_loss: 5.4351 - val_y1_output_root_mean_squared_error: 1.3375 - val_y2_output_root_mean_squared_error: 2.3336
# Epoch 120/500
# 614/614 [==============================] - 0s 169us/sample - loss: 2.0588 - y1_output_loss: 0.5096 - y2_output_loss: 1.5418 - y1_output_root_mean_squared_error: 0.7128 - y2_output_root_mean_squared_error: 1.2453 - val_loss: 2.0655 - val_y1_output_loss: 0.3882 - val_y2_output_loss: 1.6460 - val_y1_output_root_mean_squared_error: 0.6341 - val_y2_output_root_mean_squared_error: 1.2897
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 183us/sample - loss: 0.3837 - y1_output_loss: 0.1036 - y2_output_loss: 0.2864 - y1_output_root_mean_squared_error: 0.3202 - y2_output_root_mean_squared_error: 0.5303 - val_loss: 2.2400 - val_y1_output_loss: 0.6029 - val_y2_output_loss: 1.6009 - val_y1_output_root_mean_squared_error: 0.7824 - val_y2_output_root_mean_squared_error: 1.2759
# Epoch 462/500
# 614/614 [==============================] - 0s 164us/sample - loss: 0.3785 - y1_output_loss: 0.1183 - y2_output_loss: 0.2585 - y1_output_root_mean_squared_error: 0.3436 - y2_output_root_mean_squared_error: 0.5104 - val_loss: 0.8853 - val_y1_output_loss: 0.3094 - val_y2_output_loss: 0.5649 - val_y1_output_root_mean_squared_error: 0.5566 - val_y2_output_root_mean_squared_error: 0.7586
# Epoch 463/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4334 - y1_output_loss: 0.1018 - y2_output_loss: 0.3391 - y1_output_root_mean_squared_error: 0.3188 - y2_output_root_mean_squared_error: 0.5760 - val_loss: 1.7979 - val_y1_output_loss: 0.6919 - val_y2_output_loss: 1.0712 - val_y1_output_root_mean_squared_error: 0.8459 - val_y2_output_root_mean_squared_error: 1.0404
# Epoch 464/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4841 - y1_output_loss: 0.1385 - y2_output_loss: 0.3432 - y1_output_root_mean_squared_error: 0.3720 - y2_output_root_mean_squared_error: 0.5880 - val_loss: 0.7289 - val_y1_output_loss: 0.2269 - val_y2_output_loss: 0.4968 - val_y1_output_root_mean_squared_error: 0.4832 - val_y2_output_root_mean_squared_error: 0.7039
# Epoch 465/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.5954 - y1_output_loss: 0.1309 - y2_output_loss: 0.4607 - y1_output_root_mean_squared_error: 0.3632 - y2_output_root_mean_squared_error: 0.6808 - val_loss: 1.0351 - val_y1_output_loss: 0.2580 - val_y2_output_loss: 0.7681 - val_y1_output_root_mean_squared_error: 0.5146 - val_y2_output_root_mean_squared_error: 0.8777
# Epoch 466/500
# 614/614 [==============================] - 0s 172us/sample - loss: 0.4127 - y1_output_loss: 0.1099 - y2_output_loss: 0.3026 - y1_output_root_mean_squared_error: 0.3321 - y2_output_root_mean_squared_error: 0.5500 - val_loss: 1.1548 - val_y1_output_loss: 0.3012 - val_y2_output_loss: 0.8500 - val_y1_output_root_mean_squared_error: 0.5551 - val_y2_output_root_mean_squared_error: 0.9202
# Epoch 467/500
# 614/614 [==============================] - 0s 186us/sample - loss: 0.3315 - y1_output_loss: 0.1058 - y2_output_loss: 0.2245 - y1_output_root_mean_squared_error: 0.3259 - y2_output_root_mean_squared_error: 0.4746 - val_loss: 0.7878 - val_y1_output_loss: 0.2058 - val_y2_output_loss: 0.5693 - val_y1_output_root_mean_squared_error: 0.4609 - val_y2_output_root_mean_squared_error: 0.7585
# Epoch 468/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.3124 - y1_output_loss: 0.0946 - y2_output_loss: 0.2177 - y1_output_root_mean_squared_error: 0.3061 - y2_output_root_mean_squared_error: 0.4677 - val_loss: 1.2090 - val_y1_output_loss: 0.4135 - val_y2_output_loss: 0.7809 - val_y1_output_root_mean_squared_error: 0.6484 - val_y2_output_root_mean_squared_error: 0.8880
# Epoch 469/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.4078 - y1_output_loss: 0.1334 - y2_output_loss: 0.2719 - y1_output_root_mean_squared_error: 0.3658 - y2_output_root_mean_squared_error: 0.5234 - val_loss: 0.7373 - val_y1_output_loss: 0.2259 - val_y2_output_loss: 0.5039 - val_y1_output_root_mean_squared_error: 0.4793 - val_y2_output_root_mean_squared_error: 0.7124
# Epoch 470/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.3424 - y1_output_loss: 0.1053 - y2_output_loss: 0.2353 - y1_output_root_mean_squared_error: 0.3241 - y2_output_root_mean_squared_error: 0.4872 - val_loss: 0.6908 - val_y1_output_loss: 0.1955 - val_y2_output_loss: 0.4825 - val_y1_output_root_mean_squared_error: 0.4495 - val_y2_output_root_mean_squared_error: 0.6991
# Epoch 471/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.4365 - y1_output_loss: 0.1197 - y2_output_loss: 0.3176 - y1_output_root_mean_squared_error: 0.3473 - y2_output_root_mean_squared_error: 0.5621 - val_loss: 1.4036 - val_y1_output_loss: 0.2798 - val_y2_output_loss: 1.1210 - val_y1_output_root_mean_squared_error: 0.5346 - val_y2_output_root_mean_squared_error: 1.0573
# Epoch 472/500
# 614/614 [==============================] - 0s 183us/sample - loss: 0.6136 - y1_output_loss: 0.1429 - y2_output_loss: 0.4689 - y1_output_root_mean_squared_error: 0.3796 - y2_output_root_mean_squared_error: 0.6852 - val_loss: 1.0469 - val_y1_output_loss: 0.3396 - val_y2_output_loss: 0.6916 - val_y1_output_root_mean_squared_error: 0.5902 - val_y2_output_root_mean_squared_error: 0.8357
# Epoch 473/500
# 614/614 [==============================] - 0s 174us/sample - loss: 0.4717 - y1_output_loss: 0.1456 - y2_output_loss: 0.3304 - y1_output_root_mean_squared_error: 0.3801 - y2_output_root_mean_squared_error: 0.5720 - val_loss: 0.9387 - val_y1_output_loss: 0.2125 - val_y2_output_loss: 0.7197 - val_y1_output_root_mean_squared_error: 0.4677 - val_y2_output_root_mean_squared_error: 0.8485
# Epoch 474/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.3635 - y1_output_loss: 0.1050 - y2_output_loss: 0.2648 - y1_output_root_mean_squared_error: 0.3203 - y2_output_root_mean_squared_error: 0.5108 - val_loss: 1.5002 - val_y1_output_loss: 0.4787 - val_y2_output_loss: 1.0351 - val_y1_output_root_mean_squared_error: 0.6898 - val_y2_output_root_mean_squared_error: 1.0121
# Epoch 475/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.5357 - y1_output_loss: 0.1618 - y2_output_loss: 0.3717 - y1_output_root_mean_squared_error: 0.4032 - y2_output_root_mean_squared_error: 0.6109 - val_loss: 0.8430 - val_y1_output_loss: 0.2226 - val_y2_output_loss: 0.6047 - val_y1_output_root_mean_squared_error: 0.4765 - val_y2_output_root_mean_squared_error: 0.7848
# Epoch 476/500
# 614/614 [==============================] - 0s 176us/sample - loss: 0.3533 - y1_output_loss: 0.1191 - y2_output_loss: 0.2331 - y1_output_root_mean_squared_error: 0.3455 - y2_output_root_mean_squared_error: 0.4837 - val_loss: 1.1336 - val_y1_output_loss: 0.3360 - val_y2_output_loss: 0.7855 - val_y1_output_root_mean_squared_error: 0.5830 - val_y2_output_root_mean_squared_error: 0.8909
# Epoch 477/500
# 614/614 [==============================] - 0s 192us/sample - loss: 0.2993 - y1_output_loss: 0.1023 - y2_output_loss: 0.1949 - y1_output_root_mean_squared_error: 0.3208 - y2_output_root_mean_squared_error: 0.4431 - val_loss: 0.7826 - val_y1_output_loss: 0.2414 - val_y2_output_loss: 0.5299 - val_y1_output_root_mean_squared_error: 0.4982 - val_y2_output_root_mean_squared_error: 0.7311
# Epoch 478/500
# 614/614 [==============================] - 0s 198us/sample - loss: 0.3281 - y1_output_loss: 0.0952 - y2_output_loss: 0.2327 - y1_output_root_mean_squared_error: 0.3060 - y2_output_root_mean_squared_error: 0.4843 - val_loss: 0.7268 - val_y1_output_loss: 0.2260 - val_y2_output_loss: 0.4894 - val_y1_output_root_mean_squared_error: 0.4824 - val_y2_output_root_mean_squared_error: 0.7029
# Epoch 479/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.4757 - y1_output_loss: 0.1296 - y2_output_loss: 0.3453 - y1_output_root_mean_squared_error: 0.3588 - y2_output_root_mean_squared_error: 0.5891 - val_loss: 0.8228 - val_y1_output_loss: 0.2308 - val_y2_output_loss: 0.5786 - val_y1_output_root_mean_squared_error: 0.4876 - val_y2_output_root_mean_squared_error: 0.7649
# Epoch 480/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.4377 - y1_output_loss: 0.1030 - y2_output_loss: 0.3315 - y1_output_root_mean_squared_error: 0.3222 - y2_output_root_mean_squared_error: 0.5779 - val_loss: 0.7070 - val_y1_output_loss: 0.2240 - val_y2_output_loss: 0.4726 - val_y1_output_root_mean_squared_error: 0.4785 - val_y2_output_root_mean_squared_error: 0.6914
# Epoch 481/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.6126 - y1_output_loss: 0.1480 - y2_output_loss: 0.4646 - y1_output_root_mean_squared_error: 0.3863 - y2_output_root_mean_squared_error: 0.6807 - val_loss: 0.8207 - val_y1_output_loss: 0.2321 - val_y2_output_loss: 0.5766 - val_y1_output_root_mean_squared_error: 0.4886 - val_y2_output_root_mean_squared_error: 0.7629
# Epoch 482/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.4678 - y1_output_loss: 0.1138 - y2_output_loss: 0.3505 - y1_output_root_mean_squared_error: 0.3381 - y2_output_root_mean_squared_error: 0.5946 - val_loss: 0.7987 - val_y1_output_loss: 0.2306 - val_y2_output_loss: 0.5537 - val_y1_output_root_mean_squared_error: 0.4869 - val_y2_output_root_mean_squared_error: 0.7494
# Epoch 483/500
# 614/614 [==============================] - 0s 183us/sample - loss: 0.4045 - y1_output_loss: 0.1050 - y2_output_loss: 0.3007 - y1_output_root_mean_squared_error: 0.3249 - y2_output_root_mean_squared_error: 0.5468 - val_loss: 1.3663 - val_y1_output_loss: 0.3581 - val_y2_output_loss: 0.9737 - val_y1_output_root_mean_squared_error: 0.6084 - val_y2_output_root_mean_squared_error: 0.9981
# Epoch 484/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.4212 - y1_output_loss: 0.1288 - y2_output_loss: 0.2915 - y1_output_root_mean_squared_error: 0.3600 - y2_output_root_mean_squared_error: 0.5399 - val_loss: 0.9760 - val_y1_output_loss: 0.2435 - val_y2_output_loss: 0.7295 - val_y1_output_root_mean_squared_error: 0.5002 - val_y2_output_root_mean_squared_error: 0.8520
# Epoch 485/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3090 - y1_output_loss: 0.0957 - y2_output_loss: 0.2108 - y1_output_root_mean_squared_error: 0.3108 - y2_output_root_mean_squared_error: 0.4609 - val_loss: 0.6891 - val_y1_output_loss: 0.2169 - val_y2_output_loss: 0.4576 - val_y1_output_root_mean_squared_error: 0.4720 - val_y2_output_root_mean_squared_error: 0.6829
# Epoch 486/500
# 614/614 [==============================] - 0s 169us/sample - loss: 0.3601 - y1_output_loss: 0.1068 - y2_output_loss: 0.2519 - y1_output_root_mean_squared_error: 0.3268 - y2_output_root_mean_squared_error: 0.5033 - val_loss: 0.7709 - val_y1_output_loss: 0.2526 - val_y2_output_loss: 0.5085 - val_y1_output_root_mean_squared_error: 0.5078 - val_y2_output_root_mean_squared_error: 0.7163
# Epoch 487/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3841 - y1_output_loss: 0.1139 - y2_output_loss: 0.2759 - y1_output_root_mean_squared_error: 0.3307 - y2_output_root_mean_squared_error: 0.5241 - val_loss: 1.2588 - val_y1_output_loss: 0.3495 - val_y2_output_loss: 0.8993 - val_y1_output_root_mean_squared_error: 0.5968 - val_y2_output_root_mean_squared_error: 0.9501
# Epoch 488/500
# 614/614 [==============================] - 0s 185us/sample - loss: 0.4495 - y1_output_loss: 0.1197 - y2_output_loss: 0.3439 - y1_output_root_mean_squared_error: 0.3465 - y2_output_root_mean_squared_error: 0.5739 - val_loss: 1.8298 - val_y1_output_loss: 0.2649 - val_y2_output_loss: 1.5299 - val_y1_output_root_mean_squared_error: 0.5186 - val_y2_output_root_mean_squared_error: 1.2493
# Epoch 489/500
# 614/614 [==============================] - 0s 176us/sample - loss: 0.3658 - y1_output_loss: 0.1089 - y2_output_loss: 0.2542 - y1_output_root_mean_squared_error: 0.3311 - y2_output_root_mean_squared_error: 0.5062 - val_loss: 0.6854 - val_y1_output_loss: 0.1858 - val_y2_output_loss: 0.4923 - val_y1_output_root_mean_squared_error: 0.4383 - val_y2_output_root_mean_squared_error: 0.7023
# Epoch 490/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.3649 - y1_output_loss: 0.1048 - y2_output_loss: 0.2574 - y1_output_root_mean_squared_error: 0.3249 - y2_output_root_mean_squared_error: 0.5093 - val_loss: 0.7855 - val_y1_output_loss: 0.2409 - val_y2_output_loss: 0.5328 - val_y1_output_root_mean_squared_error: 0.4968 - val_y2_output_root_mean_squared_error: 0.7340
# Epoch 491/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.3348 - y1_output_loss: 0.0984 - y2_output_loss: 0.2359 - y1_output_root_mean_squared_error: 0.3147 - y2_output_root_mean_squared_error: 0.4856 - val_loss: 0.7278 - val_y1_output_loss: 0.2151 - val_y2_output_loss: 0.5058 - val_y1_output_root_mean_squared_error: 0.4701 - val_y2_output_root_mean_squared_error: 0.7119
# Epoch 492/500
# 614/614 [==============================] - 0s 174us/sample - loss: 0.4407 - y1_output_loss: 0.1267 - y2_output_loss: 0.3100 - y1_output_root_mean_squared_error: 0.3574 - y2_output_root_mean_squared_error: 0.5594 - val_loss: 0.7300 - val_y1_output_loss: 0.2256 - val_y2_output_loss: 0.4938 - val_y1_output_root_mean_squared_error: 0.4819 - val_y2_output_root_mean_squared_error: 0.7056
# Epoch 493/500
# 614/614 [==============================] - 0s 180us/sample - loss: 0.4204 - y1_output_loss: 0.1130 - y2_output_loss: 0.3064 - y1_output_root_mean_squared_error: 0.3352 - y2_output_root_mean_squared_error: 0.5550 - val_loss: 0.7757 - val_y1_output_loss: 0.2183 - val_y2_output_loss: 0.5479 - val_y1_output_root_mean_squared_error: 0.4750 - val_y2_output_root_mean_squared_error: 0.7417
# Epoch 494/500
# 614/614 [==============================] - 0s 182us/sample - loss: 0.4331 - y1_output_loss: 0.1060 - y2_output_loss: 0.3291 - y1_output_root_mean_squared_error: 0.3257 - y2_output_root_mean_squared_error: 0.5719 - val_loss: 1.4698 - val_y1_output_loss: 0.3921 - val_y2_output_loss: 1.0673 - val_y1_output_root_mean_squared_error: 0.6279 - val_y2_output_root_mean_squared_error: 1.0371
# Epoch 495/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.3435 - y1_output_loss: 0.6337 - y2_output_loss: 1.6904 - y1_output_root_mean_squared_error: 0.7996 - y2_output_root_mean_squared_error: 1.3054 - val_loss: 1.0544 - val_y1_output_loss: 0.3532 - val_y2_output_loss: 0.6827 - val_y1_output_root_mean_squared_error: 0.6029 - val_y2_output_root_mean_squared_error: 0.8312
# Epoch 496/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.3595 - y1_output_loss: 0.1044 - y2_output_loss: 0.2546 - y1_output_root_mean_squared_error: 0.3224 - y2_output_root_mean_squared_error: 0.5055 - val_loss: 1.1068 - val_y1_output_loss: 0.2315 - val_y2_output_loss: 0.8660 - val_y1_output_root_mean_squared_error: 0.4876 - val_y2_output_root_mean_squared_error: 0.9322
# Epoch 497/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.2808 - y1_output_loss: 0.0944 - y2_output_loss: 0.1876 - y1_output_root_mean_squared_error: 0.3056 - y2_output_root_mean_squared_error: 0.4328 - val_loss: 0.8541 - val_y1_output_loss: 0.2369 - val_y2_output_loss: 0.6142 - val_y1_output_root_mean_squared_error: 0.4897 - val_y2_output_root_mean_squared_error: 0.7838
# Epoch 498/500
# 614/614 [==============================] - 0s 182us/sample - loss: 0.3333 - y1_output_loss: 0.0995 - y2_output_loss: 0.2354 - y1_output_root_mean_squared_error: 0.3096 - y2_output_root_mean_squared_error: 0.4873 - val_loss: 1.4123 - val_y1_output_loss: 0.6301 - val_y2_output_loss: 0.8082 - val_y1_output_root_mean_squared_error: 0.7886 - val_y2_output_root_mean_squared_error: 0.8891
# Epoch 499/500
# 614/614 [==============================] - 0s 194us/sample - loss: 0.2932 - y1_output_loss: 0.1058 - y2_output_loss: 0.1869 - y1_output_root_mean_squared_error: 0.3259 - y2_output_root_mean_squared_error: 0.4324 - val_loss: 0.8280 - val_y1_output_loss: 0.2309 - val_y2_output_loss: 0.5852 - val_y1_output_root_mean_squared_error: 0.4873 - val_y2_output_root_mean_squared_error: 0.7685
# Epoch 500/500
# 614/614 [==============================] - 0s 179us/sample - loss: 0.2813 - y1_output_loss: 0.0941 - y2_output_loss: 0.1858 - y1_output_root_mean_squared_error: 0.3071 - y2_output_root_mean_squared_error: 0.4324 - val_loss: 0.6685 - val_y1_output_loss: 0.2067 - val_y2_output_loss: 0.4522 - val_y1_output_root_mean_squared_error: 0.4611 - val_y2_output_root_mean_squared_error: 0.6752

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 50us/sample - loss: 0.6685 - y1_output_loss: 0.2071 - y2_output_loss: 0.4611 - y1_output_root_mean_squared_error: 0.4611 - y2_output_root_mean_squared_error: 0.6752
# Loss = 0.6685449450046985, Y1_loss = 0.20712289214134216, Y1_mse = 0.46112826466560364, Y2_loss = 0.46111196279525757, Y2_mse = 0.6752079129219055

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
